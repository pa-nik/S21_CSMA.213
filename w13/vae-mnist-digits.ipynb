# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras import backend as K
from keras import objectives
from scipy.stats import norm

# %%
# data load
(x_tr, y_tr), (x_te, y_te) = mnist.load_data()
x_tr, x_te = x_tr.astype('float32')/255., x_te.astype('float32')/255.
x_tr, x_te = x_tr.reshape(x_tr.shape[0], -1), x_te.reshape(x_te.shape[0], -1)
print(x_tr.shape, x_te.shape)

# network parameters
batch_size, n_epoch = 100, 100
n_hidden, z_dim = 256, 2
# Out:
# (60000, 784) (10000, 784)

# %%
# encoder
x = Input(shape=(x_tr.shape[1:]))
x_encoded = Dense(n_hidden, activation='relu')(x)
x_encoded = Dense(n_hidden//2, activation='relu')(x_encoded)

mu = Dense(z_dim)(x_encoded)
log_var = Dense(z_dim)(x_encoded)

# %%
# sampling function
def sampling(args):
    mu, log_var = args
    eps = K.random_normal(shape=(batch_size, z_dim), mean=0., stddev=1.0)
    return mu + K.exp(log_var) * eps

z = Lambda(sampling, output_shape=(z_dim,))([mu, log_var])

# %%
# decoder
z_decoder1 = Dense(n_hidden//2, activation='relu')
z_decoder2 = Dense(n_hidden, activation='relu')
y_decoder = Dense(x_tr.shape[1], activation='sigmoid')

z_decoded = z_decoder1(z)
z_decoded = z_decoder2(z_decoded)
y = y_decoder(z_decoded)

# %%
# loss
reconstruction_loss = objectives.binary_crossentropy(x, y) * x_tr.shape[1]
kl_loss = 0.5 * K.sum(K.square(mu) + K.exp(log_var) - log_var - 1, axis = -1)
vae_loss = reconstruction_loss + kl_loss

# build model
vae = Model(x, y)
vae.add_loss(vae_loss)
vae.compile(optimizer='rmsprop')
vae.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 784)]        0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          200960      input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          32896       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            258         dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            258         dense_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (100, 2)             0           dense_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (100, 128)           384         lambda[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (100, 256)           33024       dense_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (100, 784)           201488      dense_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Minimum (TensorFlow [(100, 784)]         0           dense_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Maximum (TensorFlow [(100, 784)]         0           tf_op_layer_Minimum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_1 (TensorFlowOp [(100, 784)]         0           tf_op_layer_Maximum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(100, 784)]         0           tf_op_layer_Maximum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(100, 784)]         0           tf_op_layer_Sub_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(100, 784)]         0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub (TensorFlowOpLa [(None, 784)]        0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log_1 (TensorFlowOp [(100, 784)]         0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square (TensorFlowO [(None, 2)]          0           dense_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp (TensorFlowOpLa [(None, 2)]          0           dense_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul (TensorFlowOpLa [(100, 784)]         0           input_1[0][0]
#                                                                  tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(100, 784)]         0           tf_op_layer_Sub[0][0]
#                                                                  tf_op_layer_Log_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_3 (TensorFlow [(None, 2)]          0           tf_op_layer_Square[0][0]
#                                                                  tf_op_layer_Exp[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(100, 784)]         0           tf_op_layer_Mul[0][0]
#                                                                  tf_op_layer_Mul_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_2 (TensorFlowOp [(None, 2)]          0           tf_op_layer_AddV2_3[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Neg (TensorFlowOpLa [(100, 784)]         0           tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_3 (TensorFlowOp [(None, 2)]          0           tf_op_layer_Sub_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean (TensorFlowOpL [(100,)]             0           tf_op_layer_Neg[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum (TensorFlowOpLa [(None,)]            0           tf_op_layer_Sub_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(100,)]             0           tf_op_layer_Mean[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_3 (TensorFlowOp [(None,)]            0           tf_op_layer_Sum[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_4 (TensorFlow [(100,)]             0           tf_op_layer_Mul_2[0][0]
#                                                                  tf_op_layer_Mul_3[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              (100,)               0           tf_op_layer_AddV2_4[0][0]
# ==================================================================================================
# Total params: 469,268
# Trainable params: 469,268
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# train
vae.fit(x_tr,
       shuffle=True,
       epochs=n_epoch,
       batch_size=batch_size,
       validation_data=(x_te, None), verbose=1)
# Out:
# Epoch 1/100
# 600/600 [==============================] - 3s 5ms/step - loss: 182.9024 - val_loss: 165.8116
# Epoch 2/100
# 600/600 [==============================] - 3s 4ms/step - loss: 161.1441 - val_loss: 156.8258
# Epoch 3/100
# 600/600 [==============================] - 3s 4ms/step - loss: 154.3672 - val_loss: 152.8299
# Epoch 4/100
# 600/600 [==============================] - 3s 4ms/step - loss: 151.0925 - val_loss: 149.7999
# Epoch 5/100
# 600/600 [==============================] - 3s 5ms/step - loss: 148.9796 - val_loss: 148.1648
# Epoch 6/100
# 600/600 [==============================] - 3s 5ms/step - loss: 147.4919 - val_loss: 147.4325
# Epoch 7/100
# 600/600 [==============================] - 3s 5ms/step - loss: 146.2751 - val_loss: 146.5401
# Epoch 8/100
# 600/600 [==============================] - 3s 5ms/step - loss: 145.2301 - val_loss: 144.6468
# Epoch 9/100
# 600/600 [==============================] - 3s 5ms/step - loss: 144.2919 - val_loss: 143.7408
# Epoch 10/100
# 600/600 [==============================] - 3s 5ms/step - loss: 143.4126 - val_loss: 143.0052
# Epoch 11/100
# 600/600 [==============================] - 3s 6ms/step - loss: 142.7239 - val_loss: 143.1507
# Epoch 12/100
# 600/600 [==============================] - 3s 5ms/step - loss: 142.1755 - val_loss: 143.0878
# Epoch 13/100
# 600/600 [==============================] - 3s 5ms/step - loss: 141.5873 - val_loss: 141.7175
# Epoch 14/100
# 600/600 [==============================] - 3s 5ms/step - loss: 141.1522 - val_loss: 141.3485
# Epoch 15/100
# 600/600 [==============================] - 3s 5ms/step - loss: 140.8275 - val_loss: 141.6854
# Epoch 16/100
# 600/600 [==============================] - 3s 5ms/step - loss: 140.4983 - val_loss: 140.9053
# Epoch 17/100
# 600/600 [==============================] - 3s 5ms/step - loss: 140.1096 - val_loss: 140.4592
# Epoch 18/100
# 600/600 [==============================] - 3s 5ms/step - loss: 139.6120 - val_loss: 140.5795
# Epoch 19/100
# 600/600 [==============================] - 3s 5ms/step - loss: 139.2923 - val_loss: 140.0682
# Epoch 20/100
# 600/600 [==============================] - 3s 5ms/step - loss: 138.9855 - val_loss: 139.8143
# Epoch 21/100
# 600/600 [==============================] - 3s 5ms/step - loss: 138.7546 - val_loss: 140.3662
# Epoch 22/100
# 600/600 [==============================] - 3s 5ms/step - loss: 138.4751 - val_loss: 139.3890
# Epoch 23/100
# 600/600 [==============================] - 3s 5ms/step - loss: 138.2579 - val_loss: 139.4453
# Epoch 24/100
# 600/600 [==============================] - 3s 5ms/step - loss: 138.0070 - val_loss: 139.1308
# Epoch 25/100
# 600/600 [==============================] - 3s 5ms/step - loss: 137.7576 - val_loss: 138.7884
# Epoch 26/100
# 600/600 [==============================] - 3s 6ms/step - loss: 137.4933 - val_loss: 139.2202
# Epoch 27/100
# 600/600 [==============================] - 3s 5ms/step - loss: 137.4693 - val_loss: 138.4737
# Epoch 28/100
# 600/600 [==============================] - 3s 5ms/step - loss: 137.1233 - val_loss: 139.2179
# Epoch 29/100
# 600/600 [==============================] - 3s 5ms/step - loss: 136.9651 - val_loss: 138.5983
# Epoch 30/100
# 600/600 [==============================] - 3s 6ms/step - loss: 136.8450 - val_loss: 138.0437
# Epoch 31/100
# 600/600 [==============================] - 3s 6ms/step - loss: 136.6088 - val_loss: 138.0719
# Epoch 32/100
# 600/600 [==============================] - 3s 5ms/step - loss: 136.4930 - val_loss: 138.9742
# Epoch 33/100
# 600/600 [==============================] - 3s 5ms/step - loss: 136.6429 - val_loss: 138.0545
# Epoch 34/100
# 600/600 [==============================] - 3s 5ms/step - loss: 136.2990 - val_loss: 137.9853
# Epoch 35/100
# 600/600 [==============================] - 3s 5ms/step - loss: 136.2009 - val_loss: 138.2023
# Epoch 36/100
# 600/600 [==============================] - 4s 6ms/step - loss: 136.0967 - val_loss: 138.5889
# Epoch 37/100
# 600/600 [==============================] - 3s 6ms/step - loss: 135.8977 - val_loss: 138.0844
# Epoch 38/100
# 600/600 [==============================] - 3s 5ms/step - loss: 135.8995 - val_loss: 138.0691
# Epoch 39/100
# 600/600 [==============================] - 3s 5ms/step - loss: 135.8362 - val_loss: 137.8930
# Epoch 40/100
# 600/600 [==============================] - 3s 5ms/step - loss: 135.5794 - val_loss: 137.5663
# Epoch 41/100
# 600/600 [==============================] - 3s 5ms/step - loss: 135.8274 - val_loss: 137.5321
# Epoch 42/100
# 600/600 [==============================] - 3s 6ms/step - loss: 135.7737 - val_loss: 137.9588
# Epoch 43/100
# 600/600 [==============================] - 3s 5ms/step - loss: 135.6999 - val_loss: 138.1256
# Epoch 44/100
# 600/600 [==============================] - 3s 5ms/step - loss: 135.4768 - val_loss: 137.9345
# Epoch 45/100
# 600/600 [==============================] - 3s 5ms/step - loss: 135.5430 - val_loss: 137.6246
# Epoch 46/100
# 600/600 [==============================] - 3s 5ms/step - loss: 135.4138 - val_loss: 137.7206
# Epoch 47/100
# 600/600 [==============================] - 3s 5ms/step - loss: 135.1448 - val_loss: 137.8665
# Epoch 48/100
# 600/600 [==============================] - 3s 5ms/step - loss: 135.1035 - val_loss: 137.9098
# Epoch 49/100
# 600/600 [==============================] - 3s 5ms/step - loss: 135.0421 - val_loss: 137.1353
# Epoch 50/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.9360 - val_loss: 137.6567
# Epoch 51/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.8804 - val_loss: 137.7177
# Epoch 52/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.7488 - val_loss: 137.2273
# Epoch 53/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.6580 - val_loss: 137.8163
# Epoch 54/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.7606 - val_loss: 137.5778
# Epoch 55/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.7561 - val_loss: 137.7930
# Epoch 56/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.5898 - val_loss: 138.0697
# Epoch 57/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.5705 - val_loss: 137.7522
# Epoch 58/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.5555 - val_loss: 137.5334
# Epoch 59/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.6679 - val_loss: 137.4778
# Epoch 60/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.4390 - val_loss: 137.4821
# Epoch 61/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.3240 - val_loss: 137.3584
# Epoch 62/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.1994 - val_loss: 136.8314
# Epoch 63/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.1141 - val_loss: 137.6535
# Epoch 64/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.9247 - val_loss: 137.4819
# Epoch 65/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.1406 - val_loss: 138.1298
# Epoch 66/100
# 600/600 [==============================] - 3s 5ms/step - loss: 134.0668 - val_loss: 136.8652
# Epoch 67/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.9757 - val_loss: 137.8530
# Epoch 68/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.9559 - val_loss: 137.5816
# Epoch 69/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.8862 - val_loss: 137.0167
# Epoch 70/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.7729 - val_loss: 136.9924
# Epoch 71/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.7758 - val_loss: 137.1106
# Epoch 72/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.7033 - val_loss: 137.3955
# Epoch 73/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.7480 - val_loss: 137.4554
# Epoch 74/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.7038 - val_loss: 137.2731
# Epoch 75/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.6289 - val_loss: 137.6400
# Epoch 76/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.6586 - val_loss: 137.2492
# Epoch 77/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.4948 - val_loss: 137.2713
# Epoch 78/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.4969 - val_loss: 137.5347
# Epoch 79/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.5826 - val_loss: 137.8049
# Epoch 80/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.5508 - val_loss: 137.2609
# Epoch 81/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.6902 - val_loss: 136.9267
# Epoch 82/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.7418 - val_loss: 136.9286
# Epoch 83/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.5547 - val_loss: 137.3078
# Epoch 84/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.6425 - val_loss: 137.2411
# Epoch 85/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.5095 - val_loss: 137.6641
# Epoch 86/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.5648 - val_loss: 136.8466
# Epoch 87/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.4338 - val_loss: 136.9336
# Epoch 88/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.3724 - val_loss: 136.8602
# Epoch 89/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.3362 - val_loss: 137.0883
# Epoch 90/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.2743 - val_loss: 136.7616
# Epoch 91/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.3107 - val_loss: 136.7261
# Epoch 92/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.2509 - val_loss: 137.0955
# Epoch 93/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.1609 - val_loss: 136.7629
# Epoch 94/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.2616 - val_loss: 137.9351
# Epoch 95/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.2049 - val_loss: 137.4028
# Epoch 96/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.2623 - val_loss: 137.3041
# Epoch 97/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.1490 - val_loss: 137.0984
# Epoch 98/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.1291 - val_loss: 137.2680
# Epoch 99/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.0511 - val_loss: 137.0290
# Epoch 100/100
# 600/600 [==============================] - 3s 5ms/step - loss: 133.0955 - val_loss: 137.0096

# %%
# save model weights to HDF5
vae.save_weights("vae_mnist_digits_weights.h5")

# %%
# load weights into model
vae.load_weights("vae_mnist_digits_weights.h5")

# %%
# build encoder
encoder = Model(x, mu)
encoder.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 234,114
# Trainable params: 234,114
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot of the digit classes in the latent space
x_te_latent = encoder.predict(x_te, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(x_te_latent[:, 0], x_te_latent[:, 1], c=y_te)
plt.colorbar()
plt.show()

# %%
# build decoder
decoder_input = Input(shape=(z_dim,))
_z_decoded = z_decoder1(decoder_input)
_z_decoded = z_decoder2(_z_decoded)
_y = y_decoder(_z_decoded)
generator = Model(decoder_input, _y)
generator.summary()
# Out:
# Model: "functional_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_4 (Dense)              multiple                  384
# _________________________________________________________________
# dense_5 (Dense)              multiple                  33024
# _________________________________________________________________
# dense_6 (Dense)              multiple                  201488
# =================================================================
# Total params: 234,896
# Trainable params: 234,896
# Non-trainable params: 0
# _________________________________________________________________

# %%
# display a 2D manifold of the digits
n = 15 # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

grid_x = norm.ppf(np.linspace(0.05, 0.95, n)) 
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = generator.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()
